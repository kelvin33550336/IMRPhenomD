# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json

catalog_list = ['0226', '0219', '2100', '2093', '0325', '0326', '0224', '1492',
       '0225', '0221', '2099', '2098', '0220', '2095', '2094', '1503',
       '1502', '1481', '0436', '0415', '0418', '0327', '0304', '0459',
       '0370', '1124', '2092', '0159', '0218', '0228', '0389', '0328',
       '1475', '0212', '2102', '0070', '0072', '0073', '0001', '0066',
       '0086', '0067', '0071', '0068', '0090', '1137', '0152', '1135',
       '0002', '0150', '0171', '0170', '1132', '0180', '0153', '0160',
       '0148', '1154', '1122', '1155', '1123', '0158', '0149', '2089',
       '2104', '0157', '1153', '0178', '0154', '0176', '0155', '1114',
       '2086', '1141', '0215', '0230', '0151', '1477', '0366', '1134',
       '0172', '0329', '1509', '2096', '1125', '2097', '1506', '0217',
       '1497', '0330', '2085', '0213', '2091', '2087', '1476', '0211',
       '1507', '0156', '0376', '0394', '0462', '0447', '0216', '2090',
       '0227', '2088', '2101', '0214', '0585', '0229', '2103', '1495',
       '1501', '0222', '1499', '1500', '2106', '2083', '2084', '0209',
       '2105', '0210', '0232', '0231', '0004', '0005', '1376', '1498',
       '1351', '0544', '0518', '0396', '1513', '1352', '1496', '0626',
       '0311', '0523', '0198', '0312', '0313', '1353', '0318', '0310',
       '0305', '0314', '0307', '1490', '0465', '0486', '0438', '0559',
       '0475', '0409', '0503', '0535', '0386', '0398', '1223', '0591',
       '0464', '1143', '0466', '1142', '0377', '0525', '0507', '1487',
       '0315', '1508', '1474', '1493', '0306', '1505', '1471', '1482',
       '0625', '1413', '1473', '1511', '1146', '0437', '0404', '0579',
       '0361', '0369', '0392', '0019', '0025', '0441', '0385', '0008',
       '0007', '0593', '0397', '1415', '0440', '0372', '0016', '0014',
       '0013', '0012', '0009', '0194', '1470', '0499', '1480', '1479',
       '1488', '1412', '1491', '1465', '0501', '0423', '0488', '0473',
       '0435', '0355', '0414', '0566', '0512', '0451', '0550', '0382',
       '0402', '0371', '0454', '0552', '0388', '1510', '1416', '0545',
       '1414', '1354', '1469', '1466', '0580', '0530', '1478', '1504',
       '0482', '0239', '0252', '2113', '0248', '2126', '2122', '0332',
       '2117', '0243', '0258', '0399', '0333', '1222', '0410', '0233',
       '0234', '0331', '0407', '0375', '0584', '0257', '2107', '0354',
       '2108', '0334', '0335', '2128', '2121', '0574', '2132', '2131',
       '0245', '2109', '2119', '0599', '1112', '2118', '2127', '2114',
       '2115', '2123', '2116', '2124', '0253', '0247', '0238', '0235',
       '2130', '0448', '0254', '0256', '0244', '0237', '0251', '2120',
       '0249', '0242', '0240', '2111', '0554', '0184', '0255', '2112',
       '0236', '0169', '2129', '0461', '1166', '0513', '0387', '2125',
       '0412', '1164', '2110', '0241', '0250', '1167', '1165', '1148',
       '1147', '1494', '1467', '1459', '1468', '0201', '0631', '1453',
       '1472', '1512', '1454', '0259', '0191', '1462', '1461', '1484',
       '1387', '1456', '2151', '0280', '0261', '2146', '0293', '2133',
       '0260', '0279', '2145', '0274', '0292', '0273', '1221', '2152',
       '2156', '2135', '0263', '0268', '2141', '0264', '2142', '1152',
       '0277', '1151', '0046', '1150', '0285', '0291', '2139', '0045',
       '0047', '0278', '0286', '0267', '2157', '0284', '2136', '1172',
       '0275', '0269', '0287', '2153', '2159', '1175', '1174', '1173',
       '0283', '0281', '0272', '0270', '2140', '2150', '2147', '1178',
       '0262', '1179', '0266', '0290', '0183', '2138', '0168', '0265',
       '2148', '0288', '0289', '2154', '2134', '2149', '2163', '2143',
       '2160', '2162', '2144', '2265', '2137', '2158', '2155', '2161',
       '0271', '0282', '0174', '0036', '0041', '0031', '0040', '0038',
       '1485', '1446', '1447', '1483', '1457', '0200', '0317', '1489',
       '0193', '0294', '1452', '1486', '1458', '1932', '1907', '1966',
       '1962', '1936', '1942', '1911', '1938', '1906', '2018', '1937',
       '1417', '2036', '2013', '1961', '2014', '1418', '0182', '0167',
       '1931', '2040', '1220', '1451', '1450', '1449', '1434', '0190',
       '0295', '1445', '1463', '0112', '0055', '0056', '1111', '0208',
       '0110', '0109', '0187', '0296', '1428', '0197', '1440', '1443',
       '1432', '1438', '1444', '0181', '0166', '1437', '1425', '1436',
       '1424', '1439', '0297', '1464', '0192', '1442', '1435', '1448',
       '0202', '0207', '0298', '1110', '0205', '0204', '0206', '0203',
       '0188', '1427', '0299', '1429', '0195', '1421', '1422', '1426',
       '1420', '1419', '1423', '1375', '1430', '1441', '1433', '1431',
       '0063', '1455', '1460', '0064', '0114', '0186', '0300', '0199',
       '0301', '0189', '1108', '0302', '0196', '0185', '1107', '0303']

# %%
q_list = []
chi_list = []
chi1_list = []
chi2_list = []
q148_list = ['0156', '0151', '0001', '0152', '0172', '1418', '0167', '1417', '0064', '0063', '0065']

data = np.loadtxt(r'C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2neg_testing.dat', delimiter=' ')
mm_data = np.loadtxt(r'C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2neg_mismatch.dat', delimiter=' ')
name = []
for i in range(len(data[:,0])):
    code = str(int(data[i][0])).zfill(4)
    name.append(code)

for catalog_number in name:
    with open('./NR_waveform/NR_'+str(catalog_number)+'_metadata.json') as file:
        metadata = json.load(file)
        q = round(metadata['reference_mass_ratio'] * 1000) / 1000
        chi1 = metadata['reference_dimensionless_spin1'][2]
        chi2 = metadata['reference_dimensionless_spin2'][2]

        chi1_list.append(chi1)
        chi2_list.append(chi2)

        eta = q / (1 + q) ** 2.
        chi_eff = (q * chi1 + chi2) / (1 + q)
        chi_PN = chi_eff - 38 * eta * (chi1 + chi2) / 113
        chi_hat = chi_PN / (1 - 76 * eta / 113)

        q_list.append(q)
        chi_list.append(chi_PN)

q_list_train = []
chi_list_train = []
chi1_list_train = []
chi2_list_train = []

for catalog_number in q148_list:
    with open('./NR_waveform/NR_'+str(catalog_number)+'_metadata.json') as file:
        metadata = json.load(file)
        q = round(metadata['reference_mass_ratio'] * 1000) / 1000
        chi1 = metadata['reference_dimensionless_spin1'][2]
        chi2 = metadata['reference_dimensionless_spin2'][2]

        chi1_list_train.append(chi1)
        chi2_list_train.append(chi2)

        eta = q / (1 + q) ** 2.
        chi_eff = (q * chi1 + chi2) / (1 + q)
        chi_PN = chi_eff - 38 * eta * (chi1 + chi2) / 113
        chi_hat = chi_PN / (1 - 76 * eta / 113)

        q_list_train.append(q)
        chi_list_train.append(chi_PN)

# %%
q148 = np.loadtxt(r'C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat', delimiter=' ')

# %%
result_q148 = np.array([])
result_1pos2neg = np.array([])
for i in range(len(q148[:,0])):
    for j in range(len(total[:,0])):
        if q148[i][2] == total[j][2] and q148[i][3] == total[j][3]:
            result_q148 = np.append(result_q148, q148[i])
            result_1pos2neg = np.append(result_1pos2neg, total[j])

# %%
result_q148 = np.reshape(result_q148, (107, 6))
result_q148_filtered = [result_q148[i] for i in range(len(result_q148)) if result_q148[i][0] < 4*result_q148[i][1]]
result_1pos2neg = np.reshape(result_1pos2neg, (107, 6))
result_1pos2neg_filtered = [result_1pos2neg[i] for i in range(len(result_1pos2neg)) if result_1pos2neg[i][0] < 4*result_1pos2neg[i][1]]

# %%
np.savetxt(r'C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_all_f.dat', result_q148_filtered)
np.savetxt(r'C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_region_f.dat', result_1pos2neg_filtered)

# %%
train_list = pd.DataFrame([q_list_train, chi_list_train, chi1_list_train, chi2_list_train]).transpose()
train_list.to_csv('C:\CUHK\Additional Information\SURE Flatiron Research\IMRPhenomD\plotting_data\\ps_test_train.dat', header=None, index=False, sep=' ')

# %%
q_list = np.array(q_list)
total = pd.DataFrame(np.array([q_list/(1+q_list)*50, 1/(1+q_list)*50, chi1_list, chi2_list, mm_data[:,4], mm_data[:,5]]).T)
total = np.array(total)
display(total)
# total.to_csv('C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2pos_hist.dat', header=None, index=False, sep=' ')
# Out:
# array([[ 2.50000000e+01,  2.50000000e+01,  5.00006785e-01,
#         -8.99703034e-01,  2.14126459e-04,  4.04891490e-04],
#        [ 2.50000000e+01,  2.50000000e+01,  4.99980907e-01,
#         -8.99647862e-01,  4.69315457e-04,  7.71947580e-04],
#        [ 2.50000000e+01,  2.50000000e+01,  5.55961806e-05,
#         -7.99738844e-01,  2.93507699e-04,  5.69403234e-04],
#        [ 2.50000000e+01,  2.50000000e+01,  4.00002613e-01,
#         -7.99832698e-01,  2.35720421e-04,  4.55023200e-04],
#        [ 2.50000000e+01,  2.50000000e+01,  3.99960579e-01,
#         -7.99858414e-01,  4.05403451e-04,  6.93521485e-04],
#        [ 2.50000000e+01,  2.50000000e+01,  1.99908554e-01,
#         -4.00078127e-01,  6.12217053e-04,  9.22644778e-04],
#        [ 2.50000000e+01,  2.50000000e+01,  1.99950181e-01,
#         -4.80896917e-05,  9.34716991e-04,  1.38684216e-03],
#        [ 2.50000000e+01,  2.50000000e+01,  1.99950923e-01,
#         -5.20207408e-05,  9.96263451e-04,  1.26906293e-03],
# ...

# %%
# log_diff = np.log10(data[:,2]/data[:,1])
logdiff = np.log10(data[:,1])
cm = plt.cm.get_cmap('RdYlBu')
colors = logdiff
sc = plt.scatter(q_list, chi_list, c=colors, vmin=-4, vmax=-1, s=30, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{ori}})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$q$')
plt.ylabel('$\chi_{\mathrm{PN}}$')
# plt.savefig('./figures/param_space/ps_q148_qchi.pdf', dpi=5000, bbox_inches = 'tight')
plt.show()

# %%
# log_diff = np.log10(data[:,2]/data[:,1])
logdiff = np.log10(data[:,2])
cm = plt.cm.get_cmap('RdYlBu')
colors = logdiff
sc = plt.scatter(q_list, chi_list, c=colors, vmin=-4, vmax=-1, s=30, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{opt}})})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$q$')
plt.ylabel('$\chi_{\mathrm{PN}}$')
# plt.savefig('./figures/param_space/ps_q148_qchi.pdf', dpi=5000, bbox_inches = 'tight')
plt.show()

# %%
log_diff = np.log10(data[:,2]/data[:,1])
plt.scatter(q_list, chi_list, s=30, label='testing')
plt.scatter(q_list_train, chi_list_train, s=100, label='training')
plt.legend()
plt.xlabel('$q$')
plt.ylabel('$\chi_{\mathrm{PN}}$')
plt.savefig('./figures/param_space/intrin_space.pdf', dpi=5000, bbox_inches = 'tight')
# plt.show()

# %%
data = pd.read_csv('./plotting_data/q148_fl_testing.dat', delimiter=' ', header=None)
bins = np.arange(-5, -1, 0.125)
plt.hist(np.log10(data[1]).values, bins=bins, alpha=0.6, label='original')
plt.hist(np.log10(data[2].values), bins=bins, alpha=0.6, label='optimized')
# plt.axvline(np.mean(log_diff), color='orange', label='mean = %.4f' % np.mean(log_diff))
plt.legend()
plt.ylabel('Count')
plt.xlabel('$\log(\mathrm{mismatch})$')
plt.show()
# plt.savefig('mismatch/1pos2neg.pdf', dpi=5000, bbox_inches='tight')
print(np.median(data[1]))
# Out:
# 0.00169904207220415

# %%
# import matplotlib as mpl

# params = {
#     "font.size": 12,
#     "legend.fontsize": 12,
#     "legend.frameon": False,
#     "axes.labelsize": 12,
#     "axes.titlesize": 12,
#     "xtick.labelsize": 12,
#     "ytick.labelsize": 12,
#     "figure.figsize": (7, 5),
#     "xtick.top": True,
#     "axes.unicode_minus": False,
#     "ytick.right": True,
#     "xtick.bottom": True,
#     "ytick.left": True,
#     "xtick.major.pad": 8,
#     "xtick.major.size": 8,
#     "xtick.minor.size": 4,
#     "ytick.major.size": 8,
#     "ytick.minor.size": 4,
#     "xtick.direction": "in",
#     "ytick.direction": "in",
#     "axes.linewidth": 1.5,
#     "text.usetex": False,
#     # "font.family": "serif",
#     # "font.serif": "cmr10",
#     # "mathtext.fontset": "cm",
#     "axes.formatter.use_mathtext": True,  # needed when using cm=cmr10 for normal text
# }


# mpl.rcParams.update(params)

# %%
data1 = pd.read_csv('./plotting_data/1pos2pos_testing.dat', delimiter=' ', header=None)
data2 = pd.read_csv('./plotting_data/1neg2pos_testing.dat', delimiter=' ', header=None)
data3 = pd.read_csv('./plotting_data/1neg2neg_testing.dat', delimiter=' ', header=None)
data4 = pd.read_csv('./plotting_data/1pos2neg_testing.dat', delimiter=' ', header=None)
data = pd.read_csv('./plotting_data/all_quadrants.dat', delimiter=' ', header=None)
bins = np.arange(-5, -1, 0.125)

# plt.hist(np.log10(data1[2]), bins=bins, alpha=0.6, histtype="step", label='quadrant 1 opt')
# plt.hist(np.log10(data1[1]), bins=bins, alpha=0.6, histtype="step", label='quadrant 1 ori')
# plt.hist(np.log10(data2[2]), bins=bins, alpha=0.6, histtype="step", label='quadrant 2 opt')
# plt.hist(np.log10(data2[1]), bins=bins, alpha=0.6, histtype="step", label='quadrant 2 ori')
# plt.hist(np.log10(data3[2]), bins=bins, alpha=0.6, histtype="step", label='quadrant 3 opt')
# plt.hist(np.log10(data3[1]), bins=bins, alpha=0.6, histtype="step", label='quadrant 3 ori')
# plt.hist(np.log10(data4[2]), bins=bins, alpha=0.6, histtype="step", label='quadrant 4 opt')
# plt.hist(np.log10(data4[1]), bins=bins, alpha=0.6, histtype="step", label='quadrant 4 ori')
# plt.axvline(np.median(logdiff), color='orange', label='median = %.4f' % np.median(logdiff))

plt.hist(np.log10(data[1]), bins=bins, alpha=0.6, label='original')
plt.hist(np.log10(data[2]), bins=bins, alpha=0.6, label='optimized')
plt.legend()
plt.ylabel('Count')
plt.xlabel('$\log(\mathrm{mismatch})$')
# plt.show()
plt.savefig('figures/all_quadrants.pdf', dpi=5000, bbox_inches='tight')

# %%
mean = (np.mean(data[2])-np.mean(data[1]))/np.mean(data[1])
print(mean)
# Out:
# 0.10600431953793678

# %%
data
# Out:
# array([[2.26000000e+02, 2.14126459e-04, 5.58579946e-04],
#        [2.19000000e+02, 1.46123161e-04, 1.26467794e-03],
#        [2.10000000e+03, 4.69315457e-04, 3.05477075e-04],
#        ...,
#        [1.85000000e+02, 4.07014447e-03, 2.65327215e-03],
#        [1.10700000e+03, 4.93441369e-03, 3.18618398e-03],
#        [3.03000000e+02, 2.78330700e-01, 2.89928863e-01]])

# %%
import json as json
theta_intrinsic_list = []
q_list = []
chi_list = []
chi1_list = []
chi2_list = []

catalog_list = data[0].values

for catalog_number in catalog_list:
    with open('NR_waveform/NR_'+str(catalog_number)+'_metadata.json') as file:
        metadata = json.load(file)
        q = round(metadata['reference_mass_ratio'] * 1000) / 1000
        chi1 = metadata['reference_dimensionless_spin1'][2]
        chi2 = metadata['reference_dimensionless_spin2'][2]

        chi1_list.append(chi1)
        chi2_list.append(chi2)

        eta = q / (1 + q) ** 2.
        chi_eff = (q * chi1 + chi2) / (1 + q)
        chi_PN = chi_eff - 38 * eta * (chi1 + chi2) / 113
        chi_hat = chi_PN / (1 - 76 * eta / 113)

        q_list.append(q)
        chi_list.append(chi_PN)

expanded_data = pd.concat([pd.DataFrame(q_list), pd.DataFrame(chi_list), pd.DataFrame(chi1_list), pd.DataFrame(chi2_list), data[1], data[2]], axis=1)
expanded_data.columns = [0, 1, 2, 3, 4, 5]
display(expanded_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9128\2085564878.py in <module>
#       6 chi2_list = []
#       7
# ----> 8 catalog_list = data[0].values
#       9
#      10 for catalog_number in catalog_list:
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
expanded_data = pd.read_csv('C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat', delimiter=' ', header=None)
expanded_data
# Out:
#              0          1             2             3         4         5
# 0    25.000000  25.000000  5.000068e-01 -8.997030e-01  0.000214  0.000627
# 1    25.000000  25.000000 -4.999764e-01  8.998003e-01  0.000146  0.000604
# 2    25.000000  25.000000  4.999809e-01 -8.996479e-01  0.000469  0.000348
# 3    25.000000  25.000000 -4.999710e-01  8.997408e-01  0.000319  0.000436
# 4    25.000000  25.000000  5.559618e-05 -7.997388e-01  0.000294  0.000487
# ..         ...        ...           ...           ...       ...       ...
# 521  45.238095   4.761905  9.055914e-07  7.640862e-07  0.287925  0.293139
# 522  45.310888   4.689112  1.673002e-06 -2.730739e-05  0.007589  0.004053
# 523  45.450409   4.549591  1.281136e-05 -1.433890e-05  0.004070  0.001952
# 524  45.454545   4.545455  3.656198e-06  5.783880e-08  0.004934  0.002453
# 525  45.454545   4.545455  8.744045e-07  7.840362e-07  0.278331  0.291430
#
# [526 rows x 6 columns]

# %%
filtered_data = pd.DataFrame([])
for i in range(expanded_data.shape[0]):
    row = expanded_data.iloc[i]
    cond = row[0] < 4.0
    if (row[0]/row[1] < 4.0):
        filtered_data = pd.concat([filtered_data, row], axis=1)
    
filtered_data = filtered_data.T

# %%
filtered_data
# Out:
#           0       1         2         3         4         5
# 0    25.000  25.000  0.500007 -0.899703  0.000214  0.000627
# 1    25.000  25.000 -0.499976  0.899800  0.000146  0.000604
# 2    25.000  25.000  0.499981 -0.899648  0.000469  0.000348
# 3    25.000  25.000 -0.499971  0.899741  0.000319  0.000436
# 4    25.000  25.000  0.000056 -0.799739  0.000294  0.000487
# ..      ...     ...       ...       ...       ...       ...
# 435  39.998  10.002 -0.400122  0.799574  0.018654  0.008070
# 436  39.998  10.002 -0.800149 -0.799331  0.006786  0.005227
# 437  39.998  10.002  0.400044 -0.799376  0.018784  0.029672
# 438  39.998  10.002 -0.000117 -0.799390  0.000374  0.003036
# 439  39.998  10.002  0.399937  0.799502  0.033634  0.025585
#
# [440 rows x 6 columns]

# %%
m1 = filtered_data[0].values
m2 = filtered_data[1].values
chi1 = filtered_data[2].values
chi2 = filtered_data[3].values
eta = m1*m2/(m1+m2)**2

chi_PN = (m1*chi1 + m2*chi2)/(m1+m2) - 38*eta*(chi1+chi2)/113

# %%
log_diff = np.log10(filtered_data[5].values / filtered_data[4].values)

cm = plt.cm.get_cmap('RdYlBu')
colors = log_diff
sc = plt.scatter(filtered_data[2].values, filtered_data[3].values, c=colors, vmin=-1, vmax=1, s=25, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{opt}}/MM_{\mathrm{ori}})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$\chi_1$')
plt.ylabel('$\chi_2$')

# plt.axvline(0.005, color='black', linestyle='dotted')
# plt.axhline(0.005, color='black', linestyle='dotted')

# plt.savefig('/mnt/home/klam1/code/quadrant_figures/param_space_combined_logdiff.pdf', dpi=5000, bbox_inches = 'tight')
plt.show()

# %%
colors = m1/m2
sc = plt.scatter(chi_PN, log_diff, c=colors, vmin=1, vmax=4, s=15, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$q$', rotation=0, labelpad=15)
plt.xlabel('$\chi_{\mathrm{PN}}$')
plt.ylabel('$\log(MM_{\mathrm{opt}}/MM_{\mathrm{ori}})$')
# Out:
# Text(0, 0.5, '$\\log(MM_{\\mathrm{opt}}/MM_{\\mathrm{ori}})$')

# %%
log_diff = np.log10(filtered_data[5].values / filtered_data[4].values)

cm = plt.cm.get_cmap('RdYlBu')
colors = log_diff
sc = plt.scatter(filtered_data[0].values, filtered_data[1].values, c=colors, vmin=-0.75, vmax=0.75, s=25, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{opt}}/MM_{\mathrm{ori}})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$q$')
plt.ylabel('$\chi_{\mathrm{PN}}$')

# plt.axvline(0.005, color='black', linestyle='dotted')
# plt.axhline(0.005, color='black', linestyle='dotted')

plt.savefig('param_space_q148_logdiff_qchiPN.pdf', bbox_inches = 'tight')
# plt.show()

# %%
plt.hist(log_diff, bins=np.arange(-2, 2, 0.125))
plt.axvline(np.mean(log_diff), color='orange', label='mean = %.4f' % np.mean(log_diff))
plt.legend()
plt.ylabel('Count')
plt.xlabel('$\log(\mathrm{MM_{opt}}/\mathrm{MM_{IMR}})$')
plt.show()
# plt.savefig('/mnt/home/klam1/code/testing_data/MM_logdiff_q148.pdf', dpi=5000, bbox_inches='tight')

# %%
bins = np.arange(-5, -1, 0.125)
plt.hist(np.log10(data[1]).values, bins=bins, alpha=0.6, label='original')
plt.hist(np.log10(data[2].values), bins=bins, alpha=0.6, label='optimized')
# plt.axvline(np.mean(log_diff), color='orange', label='mean = %.4f' % np.mean(log_diff))
plt.legend()
plt.ylabel('Count')
plt.xlabel('$\log(\mathrm{mismatch})$')
# plt.show()
plt.savefig('mismatch/mismatch_hist_q148.pdf', dpi=5000, bbox_inches='tight')

# %%
cm = plt.cm.get_cmap('RdYlBu')
colors = np.log10(filtered_data[5].values)
sc = plt.scatter(filtered_data[2].values, filtered_data[3].values, c=colors, vmin=-4, vmax=-1, s=20, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{opt}})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$\chi_1$')
plt.ylabel('$\chi_2$')

plt.axvline(0.005, color='black', linestyle='dotted')
plt.axhline(0.005, color='black', linestyle='dotted')

plt.savefig('/mnt/home/klam1/code/quadrant_figures/param_space_combined_opt.pdf', dpi=5000, bbox_inches = 'tight')
# plt.show()

# %%
cm = plt.cm.get_cmap('RdYlBu')
colors = np.log10(filtered_data[4].values)
sc = plt.scatter(filtered_data[2].values, filtered_data[3].values, c=colors, vmin=-4, vmax=-1, s=20, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{ori}})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$\chi_1$')
plt.ylabel('$\chi_2$')

plt.axvline(0.005, color='black', linestyle='dotted')
plt.axhline(0.005, color='black', linestyle='dotted')

plt.savefig('/mnt/home/klam1/code/quadrant_figures/param_space_combined_ori.pdf', dpi=5000, bbox_inches = 'tight')
# plt.show()

# %%
data.loc[np.log10(data[2]) > -2][0].values
# Out:
# array(['0990', '0916', '0641', '0887', '0863', '0664', '0566', '1478',
#        '0737', '0248', '0716', '2122', '0332', '2121', '0991', '0917',
#        '0745', '0835', '0761', '0864', '1468', '1645', '1693', '1581',
#        '1662', '1894', '2152', '0278', '2157', '2150', '1537', '1457',
#        '1563', '1801', '1654', '1739', '1907', '1938', '2013', '2014',
#        '1990', '1440', '1432', '1438', '1437', '1426', '1488', '1535',
#        '1568', '0040', '1779', '1878', '1993', '1435', '1420', '1433',
#        '0226', '2100', '0325', '0224', '2098', '1185', '0881', '0638',
#        '1498', '1070', '0535', '0666', '0661', '1491', '0692', '0423',
#        '0473', '0545', '1466', '0580', '0252', '2126', '0258', '0940',
#        '0738', '0718', '2132', '2118', '0882', '1203', '0713', '1825',
#        '1574', '2151', '0279', '0292', '0287', '2159', '1690', '1452',
#        '1942', '1918', '1958', '2075', '1979', '2056', '1949', '1967',
# ...

# %%
deleted_data = filtered_data.drop(filtered_data[np.log10(filtered_data[5]) > -2.0].index)

# %%
deleted_data
# Out:
#          0         1         2         3         4         5
# 0    1.000 -0.632067 -0.470684 -0.793449  0.000349  0.000090
# 1    1.000 -0.599932 -0.400002 -0.799861  0.000251  0.000063
# 2    1.000 -0.599902 -0.399974 -0.799829  0.000247  0.000057
# 3    1.000 -0.300111 -0.200198 -0.400023  0.000384  0.000102
# 4    1.000 -0.200069 -0.000077 -0.400062  0.000769  0.000212
# ..     ...       ...       ...       ...       ...       ...
# 127  7.411 -0.621069 -0.610194 -0.731023  0.000724  0.003896
# 128  7.748 -0.250115 -0.200283 -0.778848  0.000689  0.007672
# 129  7.953 -0.771496 -0.800141 -0.458841  0.002268  0.001750
# 130  7.997 -0.799867 -0.799957 -0.798880  0.003826  0.001253
# 131  7.997 -0.616054 -0.603632 -0.752452  0.000846  0.005281
#
# [126 rows x 6 columns]

# %%
cm = plt.cm.get_cmap('RdYlBu')
colors = np.log10(deleted_data[5].values)
sc = plt.scatter(deleted_data[2].values, deleted_data[3].values, c=colors, vmin=-4, vmax=-2, s=30, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{opt}})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$\chi_1$')
plt.ylabel('$\chi_2$')

plt.axvline(0.005, color='black')
plt.axhline(0.005, color='black')

# plt.savefig('param_space_q148_fl.pdf', dpi=5000, bbox_inches = 'tight')
plt.show()

# %%
log_diff = np.log10(deleted_data[5].values / deleted_data[4].values)

cm = plt.cm.get_cmap('RdYlBu')
colors = np.log10(deleted_data[4].values)
sc = plt.scatter(deleted_data[2].values, deleted_data[3].values, c=colors, vmin=-4, vmax=-1, s=30, cmap=cm, alpha=0.8)
plt.colorbar(sc).ax.set_ylabel('$\log(MM_{\mathrm{opt}}/MM_{\mathrm{ori}})$', rotation=270, labelpad=15)
# plt.show()
plt.xlabel('$\chi_1$')
plt.ylabel('$\chi_2$')

plt.axvline(0.005, color='black')
plt.axhline(0.005, color='black')

# plt.savefig('param_space_q148_fl.pdf', dpi=5000, bbox_inches = 'tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# import paths

params = {
    "font.size": 15,
    "legend.fontsize": 12,
    "legend.frameon": False,
    "axes.labelsize": 15,
    "axes.titlesize": 15,
    "xtick.labelsize": 15,
    "ytick.labelsize": 15,
    "axes.unicode_minus": False,
    "figure.figsize": (11, 5),
    "xtick.top": True,
    "ytick.right": True,
    "xtick.bottom": True,
    "ytick.left": True,
    "xtick.major.pad": 8,
    "xtick.major.size": 8,
    "xtick.minor.size": 4,
    "ytick.major.size": 8,
    "ytick.minor.size": 4,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "axes.linewidth": 1.5,
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": "cmr10",
    "mathtext.fontset": "cm",
    "axes.formatter.use_mathtext": True,  # needed when using cm=cmr10 for normal text
}

mpl.rcParams.update(params)

c1 = "#102F68"
c2 = "#B02423"
c3 = "#b58500"

data1 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2pos_mismatch.dat")
data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1neg2pos_region_f.dat")
data3 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2neg_mismatch.dat")
data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_region_f.dat")

data1_q148_ = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")
data1_q148 = np.array([data1_q148_[i] for i in range(len(data1_q148_[:,0])) if data1_q148_[i,2] > 0 and data1_q148_[i,3] > 0])
data2_q148 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1neg2pos_all_f.dat")
data3_q148_ = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")
data3_q148 = np.array([data3_q148_[i] for i in range(len(data3_q148_[:,0])) if data3_q148_[i,2] < 0 and data3_q148_[i,3] < 0])
data4_q148 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_all_f.dat")

# data1 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2pos_mismatch.dat")
# data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2pos_mismatch.dat")   
# data3 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2neg_mismatch.dat")
# data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2neg_mismatch.dat")

# data_q148_ = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")
# data1_q148 = np.array([data_q148_[i] for i in range(len(data_q148_[:,0])) if data_q148_[i,2] > 0 and data_q148_[i,3] > 0])
# data2_q148 = np.array([data_q148_[i] for i in range(len(data_q148_[:,0])) if data_q148_[i,2] < 0 and data_q148_[i,3] > 0])
# data3_q148 = np.array([data_q148_[i] for i in range(len(data_q148_[:,0])) if data_q148_[i,2] < 0 and data_q148_[i,3] < 0])
# data4_q148 = np.array([data_q148_[i] for i in range(len(data_q148_[:,0])) if data_q148_[i,2] > 0 and data_q148_[i,3] < 0])

bins = np.linspace(-5, -1, 15)

fig, ax = plt.subplots(2, 2, figsize=(12, 8), sharex=True)
plt.subplots_adjust(hspace=0.05)
plt.subplots_adjust(wspace=0.04)

ax[0, 0].hist(np.log10(data1[:, 4]), bins=bins, alpha=0.2, color=c1)
ax[0, 0].hist(np.log10(data1[:, 4]), bins=bins, label="Original", color=c1, lw=2, histtype="step")
ax[0,0].axvline(x=np.log10(np.median(data1[:, 4])), color=c1,zorder=-20,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)))

ax[0, 0].hist(np.log10(data1[:, 5]),bins=bins,label="Opt. (Split)",histtype="step",color=c3,linewidth=2)
ax[0, 0].hist(np.log10(data1[:, 5]),bins=bins,color=c3,alpha=0.2)
ax[0, 0].axvline(x=np.log10(np.median(data1[:, 5])),color=c3,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)))

ax[0, 0].hist(np.log10(data1_q148[:, 5]), bins=bins, alpha=0.2, color=c2)
ax[0, 0].hist(np.log10(data1_q148[:, 5]), bins=bins, label="Opt. (All)", color=c2, lw=2, histtype="step")
ax[0, 0].axvline(x=np.log10(np.median(data1_q148[:, 5])),color=c2,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)))

ax[0, 0].set_ylabel("Count")
ax[0, 0].legend(loc="upper left")
ax[0, 0].set_xlim(-5, -0.5)
ax[0, 1].set_ylim(0, 45)
ax[0, 0].yaxis.set_ticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45])


ax[0, 1].hist(np.log10(data3[:, 4]), bins=bins, alpha=0.2, color=c1)
ax[0, 1].hist(np.log10(data3[:, 4]), bins=bins, color=c1, lw=2, histtype="step")
ax[0, 1].axvline(x=np.log10(np.median(data3[:, 4])),color=c1,zorder=-20,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)),)

ax[0, 1].hist(np.log10(data3[:, 5]),bins=bins,histtype="step",color=c3,linewidth=2)
ax[0, 1].hist(np.log10(data3[:, 5]),bins=bins,color=c3,alpha=0.2)
ax[0, 1].axvline(x=np.log10(np.median(data3[:, 5])),color=c3,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)))

ax[0, 1].hist(np.log10(data3_q148[:, 5]), bins=bins, alpha=0.2, color=c2)
ax[0, 1].hist(np.log10(data3_q148[:, 5]), bins=bins,color=c2, lw=2, histtype="step")
ax[0, 1].axvline(x=np.log10(np.median(data3_q148[:, 5])),color=c2,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)))

ax[0, 1].set_xlim(-5, -0.5)
ax[0, 1].set_ylim(0, 45)
ax[0, 1].yaxis.set_ticks([0, 5, 10, 15, 20, 25, 30, 35, 40, 45])
plt.setp(ax[0, 1].get_yticklabels(), visible=False)


ax[1, 0].hist(np.log10(data2[:, 4]), bins=bins, alpha=0.2, color=c1)
ax[1, 0].hist(np.log10(data2[:, 4]), bins=bins, histtype="step", color=c1, lw=2)
ax[1, 0].axvline(x=np.log10(np.median(data2[:, 4])),color=c1,zorder=-20,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)))

ax[1, 0].hist(np.log10(data2[:, 5]), bins=bins, histtype="step", color=c3, lw=2)
ax[1, 0].hist(np.log10(data2[:, 5]), bins=bins, color=c3, alpha=0.2)
ax[1, 0].axvline(x=np.log10(np.median(data2[:, 5])),color=c3,lw=2,alpha=1.0,linestyle=(0, (1, 1.3)))

ax[1, 0].hist(np.log10(data2_q148[:, 5]), bins=bins, alpha=0.2, color=c2)
ax[1, 0].hist(np.log10(data2_q148[:, 5]), bins=bins, color=c2, lw=2, histtype="step")
ax[1, 0].axvline(x=np.log10(np.median(data2_q148[:, 5])), color=c2, lw=2, alpha=1.0, linestyle=(0, (1, 1.3)))

ax[1, 0].set_xlabel("$\log_{10}(\mathcal{M})$")
ax[1, 0].set_ylabel("Count")
ax[1, 0].set_xlim(-5, -0.5)
ax[1, 0].set_ylim(0, 21)
ax[1, 0].yaxis.set_ticks([0, 5, 10, 15, 20])

ax[1, 1].hist(np.log10(data4[:, 4]), bins=bins, alpha=0.2, color=c1)
ax[1, 1].hist(np.log10(data4[:, 4]), bins=bins, histtype="step", color=c1, lw=2)
ax[1, 1].axvline(x=np.log10(np.median(data4[:, 4])), color=c1, zorder=-20, lw=2, alpha=1.0, linestyle=(0, (1, 1.3)))

ax[1, 1].hist(np.log10(data4[:, 5]), bins=bins, histtype="step", color=c3, lw=2)
ax[1, 1].hist(np.log10(data4[:, 5]), bins=bins, color=c3, alpha=0.2)
ax[1, 1].axvline(x=np.log10(np.median(data4[:, 5])), color=c3, lw=2, alpha=1.0, linestyle=(0, (1, 1.3)))

ax[1, 1].hist(np.log10(data4_q148[:, 5]), bins=bins, alpha=0.2, color=c2)
ax[1, 1].hist(np.log10(data4_q148[:, 5]), bins=bins, color=c2, lw=2, histtype="step")
ax[1, 1].axvline(x=np.log10(np.median(data4_q148[:, 5])), color=c2, lw=2, alpha=1.0, linestyle=(0, (1, 1.3)))

ax[1, 1].set_xlabel("$\log_{10}(\mathcal{M})$")
ax[1, 1].set_xlim(-5, -0.5)
ax[1, 1].set_ylim(0, 21)
ax[1, 1].yaxis.set_ticks([0, 5, 10, 15, 20])
plt.setp(ax[1, 1].get_yticklabels(), visible=False)

ax[0, 0].text(-1.5, 42.8, r'$\chi_1,\chi_2>0$',
        horizontalalignment='left',
        verticalalignment='top',
        fontsize=14, bbox=dict(facecolor='none', edgecolor='black', pad=3.0))
ax[0, 1].text(-1.5, 42.8, r'$\chi_1,\chi_2<0$',
        horizontalalignment='left',
        verticalalignment='top',
        fontsize=14, bbox=dict(facecolor='none', edgecolor='black', pad=3.0))
ax[1, 0].text(-1.62, 20, r'$\chi_1<0<\chi_2$',
        horizontalalignment='left',
        verticalalignment='top',
        fontsize=14, bbox=dict(facecolor='none', edgecolor='black', pad=3.0))
ax[1, 1].text(-1.62, 20, r'$\chi_1>0>\chi_2$',
        horizontalalignment='left',
        verticalalignment='top',
        fontsize=14, bbox=dict(facecolor='none', edgecolor='black', pad=3.0))
# plt.savefig(paths.figures / "all_quadrants.pdf", bbox_inches="tight")
# Out:
# Text(-1.62, 20, '$\\chi_1>0>\\chi_2$')

# %%
ax[0, 1].get_yticklabels()
# Out:
# []

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# import paths

params = {
    "font.size": 15,
    "legend.fontsize": 12,
    "legend.frameon": False,
    "axes.labelsize": 15,
    "axes.titlesize": 15,
    "xtick.labelsize": 15,
    "ytick.labelsize": 15,
    "axes.unicode_minus": False,
    "figure.figsize": (11, 5),
    "xtick.top": True,
    "ytick.right": True,
    "xtick.bottom": True,
    "ytick.left": True,
    "xtick.major.pad": 8,
    "xtick.major.size": 8,
    "xtick.minor.size": 4,
    "ytick.major.size": 8,
    "ytick.minor.size": 4,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "axes.linewidth": 1.5,
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": "cmr10",
    "mathtext.fontset": "cm",
    "axes.formatter.use_mathtext": True,  # needed when using cm=cmr10 for normal text
}

mpl.rcParams.update(params)

c1 = "#102F68"
c2 = "#B02423"
c3 = "#FFB300"

data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2pos_mismatch.dat")
data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2neg_mismatch.dat")

data = np.loadtxt("C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")
data2_q148 = np.array([data[i, 5] for i in range(len(data[:,0])) if data[i, 2] < 0 and data[i, 3] > 0])
data4_q148 = np.array([data[i, 5] for i in range(len(data[:,0])) if data[i, 2] > 0 and data[i, 3] < 0])

bins = np.linspace(-5, -1, 15)

fig, ax = plt.subplots(2, figsize=(6, 10), sharex=True)
plt.subplots_adjust(hspace=0.05)

ax[0].hist(
    np.log10(data2[:, 4]), 
    bins=bins, 
    alpha=0.2, 
    color=c1
)
ax[0].hist(
    np.log10(data2[:, 4]), 
    bins=bins, 
    label="Original", 
    color=c1, 
    lw=2, 
    histtype="step"
)
ax[0].axvline(
    x=np.log10(np.median(data2[:, 4])),
    color=c1,
    zorder=-20,
    lw=2,
    alpha=1.0,
    linestyle=(0, (1, 1.3)),
)
ax[0].hist(
    np.log10(data2[:, 5]),
    bins=bins,
    label="Optimized",
    histtype="step",
    color=c3,
    linewidth=2,
)
ax[0].hist(
    np.log10(data2[:, 5]),
    bins=bins,
    color=c3,
    alpha=0.2,
)
ax[0].axvline(
    x=np.log10(np.median(data2[:, 5])),
    color=c3,
    lw=2,
    alpha=1.0,
    linestyle=(0, (1, 1.3)),
)
ax[0].hist(
    np.log10(data2_q148), 
    bins=bins, 
    alpha=0.2, 
    color=c2
)
ax[0].hist(
    np.log10(data2_q148), 
    bins=bins, 
    label="Optimized $(\mathcal{L}_{\mathrm{ave}})$", 
    color=c2, 
    lw=2, 
    histtype="step"
)
ax[0].axvline(
    x=np.log10(np.median(data2_q148)),
    color=c2,
    lw=2,
    alpha=1.0,
    linestyle=(0, (1, 1.3)),
)
ax[0].set_ylabel("Count")
ax[0].legend(loc="upper left")

ax[1].hist(
    np.log10(data4[:, 4]), 
    bins=bins, 
    alpha=0.2, 
    color=c1
)
ax[1].hist(
    np.log10(data4[:, 4]), 
    bins=bins, 
    histtype="step", 
    color=c1, 
    lw=2
)
ax[1].axvline(
    x=np.log10(np.median(data4[:, 4])),
    color=c1,
    zorder=-20,
    lw=2,
    alpha=1.0,
    linestyle=(0, (1, 1.3)),
)
ax[1].hist(
    np.log10(data4[:, 5]), 
    bins=bins, 
    histtype="step", 
    color=c3, 
    lw=2
)
ax[1].hist(
    np.log10(data4[:, 5]), 
    bins=bins, 
    color=c3, 
    alpha=0.2
)
ax[1].axvline(
    x=np.log10(np.median(data4[:, 5])),
    color=c3,
    lw=2,
    alpha=1.0,
    linestyle=(0, (1, 1.3)),
)
ax[1].hist(
    np.log10(data4_q148), 
    bins=bins, 
    alpha=0.2, 
    color=c2
)
ax[1].hist(
    np.log10(data4_q148), 
    bins=bins, 
    color=c2, 
    lw=2, 
    histtype="step"
)
ax[1].axvline(
    x=np.log10(np.median(data4_q148)),
    color=c2,
    lw=2,
    alpha=1.0,
    linestyle=(0, (1, 1.3)),
)
ax[1].set_xlabel("$\log_{10}(\mathcal{M})$")
ax[1].set_ylabel("Count")

# plt.savefig(paths.figures / "all_quadrants.pdf", bbox_inches="tight")
# Out:
# Text(0, 0.5, 'Count')

# %%
print(np.log10(np.median(data2[:, 5])))
print(np.log10(np.median(data2_q148[:, 5])))
# Out:
# -2.9666608706916
# -3.0990936981163486

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

params = {
    "font.size": 18,
    "legend.fontsize": 12,
    "legend.frameon": False,
    "axes.labelsize": 18,
    "axes.titlesize": 18,
    "xtick.labelsize": 18,
    "ytick.labelsize": 18,
    "axes.unicode_minus": False,
    "figure.figsize": (7, 5),
    "xtick.top": True,
    "ytick.right": True,
    "xtick.bottom": True,
    "ytick.left": True,
    "xtick.major.pad": 8,
    "xtick.major.size": 8,
    "xtick.minor.size": 4,
    "ytick.major.size": 8,
    "ytick.minor.size": 4,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "axes.linewidth": 1.5,
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": "cmr10",
    "mathtext.fontset": "cm",
    "axes.formatter.use_mathtext": True,  # needed when using cm=cmr10 for normal text
}

mpl.rcParams.update(params)

data1 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2pos_mismatch.dat")
data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1neg2pos_region_f.dat")
data3 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2neg_mismatch.dat")
data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_region_f.dat")
data = np.concatenate((data1, data2, data3, data4))
# data = data2

logdiff = np.log10(data[:, 5] / data[:, 4])
cm = plt.cm.get_cmap("RdYlBu")
colors = logdiff
sc = plt.scatter(data[:, 2], data[:, 3], c=colors, vmin=-1, vmax=1, s=30, cmap=cm)
cbar = plt.colorbar(sc, ticks=[-1, -0.5, 0, 0.5, 1])
cbar.ax.set_ylabel(
    "$\log_{10}(\mathcal{M}_f/\mathcal{M}_i)$", rotation=270, labelpad=20
)
cbar.ax.set_yticklabels(["$<-1$", "$-0.5$", "$0$", "$0.5$", "$>1$"])
plt.xlabel("$\chi_1$")
plt.ylabel("$\chi_2$")
# plt.title('quadrant 2')
plt.show()

##############################################################################################################

# data1 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2pos_mismatch.dat")
# data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1neg2pos_all_f.dat")
# data3 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2neg_mismatch.dat")
# data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_all_f.dat")
# # data = np.concatenate((data1, data2, data data4))
# # data = data2

# logdiff = np.log10(data[:, 5] / data[:, 4])
# cm = plt.cm.get_cmap("jet")
# colors = logdiff
# sc = plt.scatter(data[:, 2], data[:, 3], c=colors, vmin=-1, vmax=1, s=30, cmap=cm)
# cbar = plt.colorbar(sc, ticks=[-1, -0.5, 0, 0.5, 1])
# cbar.ax.set_ylabel(
#     "$\log_{10}(\mathcal{M}_f/\mathcal{M}_i)$", rotation=270, labelpad=20
# )
# cbar.ax.set_yticklabels(["$<-1$", "$-0.5$", "$0$", "$0.5$", "$>1$"])
# plt.xlabel("$\chi_1$")
# plt.ylabel("$\chi_2$")
# plt.title('all waveforms')
# plt.show()

# %%
data1 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2pos_mismatch.dat")
data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1neg2pos_region_f.dat")
data3 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2neg_mismatch.dat")
data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_region_f.dat")
data_region = np.concatenate((data1, data2, data3, data4))

data1 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2pos_mismatch.dat")
data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1neg2pos_all_f.dat")
data3 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2neg_mismatch.dat")
data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_all_f.dat")
data_q148 = np.concatenate((data1, data2, data3, data4))

logdiff = np.log10(data_region[:, 5] / data_region[:, 4])

# fig, ax = plt.subplots(figsize=(7, 12))

# cm = plt.cm.get_cmap("RdYlBu")
# colors = logdiff
# sc = ax[0].scatter(data_region[:, 2], data_region[:, 3], c=colors, vmin=-1, vmax=1, s=30, cmap=cm)
# cbar = plt.colorbar(sc, ticks=[-1, -0.5, 0, 0.5, 1], ax=ax[0])
# cbar.ax.set_ylabel(
#     "$\log_{10}(\mathcal{M}_f/\mathcal{M}_i)$", rotation=270, labelpad=20
# )
# cbar.ax.set_yticklabels(["$<-1$", "$-0.5$", "$0$", "$0.5$", "$>1$"])
# ax[0].set_xlabel("$\chi_1$")
# ax[0].set_ylabel("$\chi_2$")

bins = np.linspace(-5, -1, 15)

plt.figure(figsize=(6, 5))
plt.hist(np.log10(data_q148[:,5]), alpha=0.2, bins=bins, color=c2)
plt.hist(np.log10(data_q148[:,5]), histtype='step', lw=2, bins=bins, color=c2, label='Opt. (All)')
plt.hist(np.log10(data_region[:,5]), alpha=0.2, bins=bins, color=c3)
plt.hist(np.log10(data_region[:,5]), histtype='step', lw=2, bins=bins, color=c3, label='Opt. (Region)')
plt.axvline(x=np.log10(np.median(data_q148[:,5])), color=c2, ls='--', lw=2)
plt.axvline(x=np.log10(np.median(data_region[:,5])), color=c3, ls='--', lw=2)
plt.xlabel("$\log_{10}(\mathcal{M})$")
plt.ylabel("Count")
plt.legend(loc='upper left')

# %%
print(np.log10(np.median(data_q148[:,5])))
print(np.log10(np.median(data_region[:,5])))
# Out:
# -3.096629617663772
# -3.0799908314147153

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

params = {
    "font.size": 18,
    "legend.fontsize": 12,
    "legend.frameon": False,
    "axes.labelsize": 18,
    "axes.titlesize": 18,
    "xtick.labelsize": 18,
    "ytick.labelsize": 18,
    "axes.unicode_minus": False,
    "figure.figsize": (7, 5),
    "xtick.top": True,
    "ytick.right": True,
    "xtick.bottom": True,
    "ytick.left": True,
    "xtick.major.pad": 8,
    "xtick.major.size": 8,
    "xtick.minor.size": 4,
    "ytick.major.size": 8,
    "ytick.minor.size": 4,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "axes.linewidth": 1.5,
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": "cmr10",
    "mathtext.fontset": "cm",
    "axes.formatter.use_mathtext": True,  # needed when using cm=cmr10 for normal text
}

mpl.rcParams.update(params)

data = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")

logdiff = np.log10(data[:, 5] / data[:, 4])
cm = plt.cm.get_cmap("jet")
colors = logdiff
sc = plt.scatter(data[:, 2], data[:, 3], c=colors, vmin=-1.5, vmax=1.5, s=30, cmap=cm)
cbar = plt.colorbar(sc, ticks=[-1, -0.5, 0, 0.5, 1])
cbar.ax.set_ylabel(
    "$\log_{10}(\mathcal{M}_f/\mathcal{M}_i)$", rotation=270, labelpad=20
)
cbar.ax.set_yticklabels(["$<-1$", "$-0.5$", "$0$", "$0.5$", "$>1$"])
plt.xlabel("$\chi_1$")
plt.ylabel("$\chi_2$")
# Out:
# Text(0, 0.5, '$\\chi_2$')

# %%
data1 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1pos2pos_mismatch.dat")
data2 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1neg2pos_region_f.dat")
data3 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\1neg2neg_mismatch.dat")
data4 = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148_1pos2neg_region_f.dat")
data_region = np.concatenate((data1, data2, data3, data4))

data = np.loadtxt(r"C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")

plt.hist(np.log10(data[:,5]), alpha=1, histtype='step', lw=2, bins=bins)
plt.hist(np.log10(data_region[:,5]), alpha=1, histtype='step', lw=2, bins=bins)
# Out:
# (array([ 0.,  1., 18., 51., 65., 58., 69., 84., 38., 32., 24., 18.,  3.,
#          3.]),
#  array([-5.        , -4.71428571, -4.42857143, -4.14285714, -3.85714286,
#         -3.57142857, -3.28571429, -3.        , -2.71428571, -2.42857143,
#         -2.14285714, -1.85714286, -1.57142857, -1.28571429, -1.        ]),
#  [<matplotlib.patches.Polygon at 0x1c3520fd760>])

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# import paths

params = {
    "font.size": 17,
    "legend.fontsize": 14,
    "legend.frameon": True,
    "axes.labelsize": 17,
    "axes.titlesize": 17,
    "xtick.labelsize": 17,
    "ytick.labelsize": 17,
    "axes.unicode_minus": False,
    "figure.figsize": (6, 5),
    "xtick.top": True,
    "ytick.right": True,
    "xtick.bottom": True,
    "ytick.left": True,
    "xtick.major.pad": 8,
    "xtick.major.size": 8,
    "xtick.minor.size": 4,
    "ytick.major.size": 8,
    "ytick.minor.size": 4,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "axes.linewidth": 1.5,
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": "cmr10",
    "mathtext.fontset": "cm",
    "axes.formatter.use_mathtext": True,  # needed when using cm=cmr10 for normal text
}

mpl.rcParams.update(params)
# blue = "#102F68"
# red = "#B02423"
c1 = "#0562ED"
c2 = "#FE6100"
c3 = '#266D1F'

train_data = np.loadtxt("C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\ps_train.dat")[:11]
add_train_data = np.loadtxt("C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\ps_train.dat")[11:]
test_data = np.loadtxt("C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")

q = test_data[:, 0] / test_data[:, 1]
eta = test_data[:, 0] * test_data[:, 1] / (test_data[:, 0] + test_data[:, 1]) ** 2
chi_PN = (test_data[:, 0] * test_data[:, 2] + test_data[:, 1] * test_data[:, 3]) / (
    test_data[:, 0] + test_data[:, 1]
) - 38 * eta * (test_data[:, 2] + test_data[:, 3]) / 113

plt.scatter(train_data[:, 0], train_data[:, 1], s=180, color=c1, label="Training", marker='*')
plt.scatter(add_train_data[:, 0], add_train_data[:, 1], s=180, color=c3, label='Extra Training', marker='*')
plt.scatter(q, chi_PN, s=3, color=c2, label="Validation", zorder=-20)
plt.legend()
plt.xlabel("$q$")
plt.ylabel("$\chi_{\mathrm{PN}}$")
# plt.savefig(paths.figures / "intrin_space.pdf", bbox_inches="tight")
# Out:
# Text(0, 0.5, '$\\chi_{\\mathrm{PN}}$')

# %%
q148_data = np.loadtxt("C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q148.dat")
q1248_data = np.loadtxt("C:\CUHK\Additional Information\SURE Flatiron Research\imrphenomd_paper\src\data\q1248.dat")

median_q148 = np.median(q148_data[:, 5])
median_q1248 = np.median(q1248_data[:, 5])

percentage_change = (median_q1248 - median_q148) / median_q148 * 100
print(percentage_change)
# Out:
# -10.75172657819077
